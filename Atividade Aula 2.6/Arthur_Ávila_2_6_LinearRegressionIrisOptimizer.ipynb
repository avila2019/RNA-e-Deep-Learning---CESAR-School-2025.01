# %% [markdown]
# # Regressão Linear com PyTorch

# %% [markdown]
# ## Objetivos

# %% [markdown]
# Este exemplo utiliza regressão linear para estimar o comprimento das sépalas da íris a partir do seu comprimento das pétalas.
# Utiliza-se:
# - a função de perda MSE do PyTorch,
# - treinamento dos parâmetros via gradiente descendente usando o otimizador.
# - A rede é criada com uma camada nn.Linear()

# %% [markdown]
# ## Importação dos pacotes

# %%
# %matplotlib inline
import torch
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

torch.manual_seed(1234)

# %% [markdown]
# ## Leitura dos dados

# %%
iris = load_iris()
data = iris.data[iris.target==1,::2]  # comprimento das sépalas e pétalas, indices 0 e 2

x_train = data[:,0:1].astype(np.float32)
y_train = data[:,1:2].astype(np.float32)

n_samples = x_train.shape[0]
print('x_train.shape:',x_train.shape, x_train.dtype)
print('y_train.shape:',y_train.shape, y_train.dtype)

print('x_train[:5]:\n', x_train[:5])
print('y_train[:5]:\n', y_train[:5])
# Out:
# x_train.shape: (50, 1) float32
# y_train.shape: (50, 1) float32
# x_train[:5]:
#  [[7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]]
# y_train[:5]:
#  [[4.7]
#  [4.5]
#  [4.9]
#  [4. ]
#  [4.6]]

# %% [markdown]
# ### Normalização dos dados

# %%
x_train -= x_train.min()
x_train /= x_train.max()
y_train -= y_train.min()
y_train /= y_train.max()

# %%
x_train_bias = np.hstack([np.ones(shape=(n_samples,1)), x_train])

# %%
x_train_bias = torch.FloatTensor(x_train_bias)
y_train      = torch.FloatTensor(y_train)

# %% [markdown]
# ## Criação do modelo da rede

# %%
model = torch.nn.Linear(2, 1, bias=False)

# %% [markdown]
# ### Verificando a inicialização dos parâmetros

# %%
model.weight.data = torch.zeros(1,2)
torch.nn.init.uniform(model.weight.data, -0.1, 0.1)
model.weight.data
# Out:
# /tmp/ipython-input-1486225639.py:2: FutureWarning: `nn.init.uniform` is now deprecated in favor of `nn.init.uniform_`.
#   torch.nn.init.uniform(model.weight.data, -0.1, 0.1)
# tensor([[-0.0480, -0.0267]])

# %% [markdown]
# ### Testando o predict da rede

# %%
model(Variable(torch.ones((5,2))))
# Out:
# tensor([[-0.0747],
#         [-0.0747],
#         [-0.0747],
#         [-0.0747],
#         [-0.0747]], grad_fn=<MmBackward0>)

# %% [markdown]
# ## Treinamento

# %% [markdown]
# ### Definindo função de perda e otimizador

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.3)

# %% [markdown]
# ### Laço de treinamento

# %%
num_epochs = 120
w0_list = []
w1_list = []
for epoch in range(num_epochs):
    inputs = x_train_bias
    target = y_train

    # forward - predict
    out = model(inputs)

    w0_list.append(model.weight.data[0][0].item())
    w1_list.append(model.weight.data[0][1].item())

    #loss cálculo da função de perda
    loss = criterion(out, target)

    # backward e otimizador
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # verbose
    if (epoch+1) % 20 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss.data))
# Out:
# Epoch[20/120], loss: 0.024990
# Epoch[40/120], loss: 0.022381
# Epoch[60/120], loss: 0.021554
# Epoch[80/120], loss: 0.021291
# Epoch[100/120], loss: 0.021208
# Epoch[120/120], loss: 0.021182

# %% [markdown]
# ## Avaliação

# %%
y_pred = model(x_train_bias)
plt.plot(x_train, y_train.numpy(), 'ro', label='Original data')
plt.plot(x_train, y_pred.data.numpy(), 'kx-', label='Fitting Line')
plt.show()

# %% [markdown]
# # Exercícios

# %% [markdown]
# - 1) Calcule o valor da função de custo (MSE) depois da rede treinada, utilizando a
#    função `criterion` utilizada no laço de treinamento.

# %%
#todo
with torch.no_grad():
    y_pred_final = model(x_train_bias)
    mse_final = criterion(y_pred_final, y_train)
    print("MSE final:", mse_final.item())
# Out:
# MSE final: 0.021181009709835052

# %% [markdown]
# <details>
# <summary>Mostrar Resultado</summary>
#
# ```python
# y_pred = model(Variable(x_train_bias))
# loss = criterion(y_pred, Variable(y_train))
# print(loss)
# ```
#
# </details>

# %% [markdown]
# - 2) Faça igual o exercício do notebook anterior, de plotar um gráfico scatterplot para
#    mostrar a evolução dos parâmetros durante o treinamento pelo gradiente descendente.

# %%
# todo

# 1) MSE com o final após treinamento

with torch.no_grad():
    y_pred_final = model(x_train_bias)
    mse_final = criterion(y_pred_final, y_train)
    print("\nMSE final (criterion):", mse_final.item())



# 2) Scatterplot da evolução dos pesos


#solução analítica dos mínimos quadrados
x_bias = x_train_bias
y = y_train
x_bias_t = torch.t(x_bias)
w_opt = (torch.inverse(x_bias_t.mm(x_bias)).mm(x_bias_t)).mm(y)
w_opt = w_opt.view(-1)  # Conversão

print("\nSolução analítica (w0, w1):", w_opt)

#   Gráfico scatter dos pesos aprendidos
plt.figure(figsize=(8,6))
plt.scatter(w0_list, w1_list, s=35, label="Treinamento (GD)")
plt.scatter(w_opt[0].item(), w_opt[1].item(),
            color='red', s=120, marker='X', label='Solução Analítica')
#Plot
plt.xlabel("w0")
plt.ylabel("w1")
plt.title("Evolução dos parâmetros (w0, w1) durante o treinamento")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MSE final (criterion): 0.021181009709835052
#
# Solução analítica (w0, w1): tensor([0.2613, 0.6865])

# %% [markdown]
# <details>
# <summary>Mostrar Resultado</summary>
#
# ```python
# plt.scatter(w0_list,w1_list)
# w0_old = None
# for (w0,w1) in zip(w0_list,w1_list):
#     if w0_old:
#         plt.arrow(w0_old, w1_old, w0-w0_old, w1-w1_old,
#                   head_length=0.01,head_width=0.01,shape='full',
#                   length_includes_head=True)
#     w0_old,w1_old = w0,w1
# ```
#
# </details>

# %% [markdown]
# # Aprendizados

# %% [markdown]
# -> O Ojetivo era treinar um modelo de regressão linear no Pytorch usando SHD, aprendemos à elaborar um modelo nn.linear, definição a função de custo MSE, como realizar uma definição de otimização com o SGD, como realizar os Forwar"Loss,backward,atualizações"
#
# -> Vimos como normalizar os dados e qual a importância desse a normalização, como a descida de gradiente se torna mais estável, como os pesos convergem mais rápido evitando que o learning rate possa pipocar.
#
# -> Na evolução dos pesos interagimos com W0_LIST e W1_ist na execução deste treino, aprendemos que os pesos mudam gradualmente a cada época que passa, os caminhos seguindos no SGD são visualizados e coinseguimos interpretar de uma forma mais eficaz, visualizando o espaço de parâmetros.
#
# -> No Gradiente no espaço W0,W1 notei que seguimos uma direção maior a redução do erro a convergência final para o último ponto.
#
# -> Realizamos o cáulo MSE no melhor formato levando em consideração a relação entre x e y,  uitilizamos o criterion(model(x),y) que é a melhor maneira no treino, pois mantém a consistência com o que a rede otimizou.
